# %% [markdown]
# # Telco Churn Analysis with Pandas
# This notebook follows along with the Pandas tutorial to explore the Telco churn dataset.

# %%
import pandas as pd

# %%
# Load the dataset (adjust the path if needed)
df = pd.read_csv(r'C:\Users\bigre\OneDrive\HomeWork\SDEV 220\telco_churn.csv')
df.head()

# %%
# Dataset summary
df.info()

# %%
# Basic statistics
df.describe()

# %%
# Check for missing values
df.isnull().sum()

# %%
# Churn distribution
df['Churn'].value_counts(normalize=True)

# %%
# Churn by International Plan
df.groupby(['International plan', 'Churn']).size()

# %%
# Mean total day minutes by churn
df.groupby('Churn')['Total day minutes'].mean()

# %%
# Sort by highest total day charge
df.sort_values('Total day charge', ascending=False).head(10)

# %%
# Create a new column with total minutes used
df['Total minutes'] = df['Total day minutes'] + df['Total eve minutes'] + df['Total night minutes'] + df['Total intl minutes']
df[['Total minutes', 'Churn']].head()
